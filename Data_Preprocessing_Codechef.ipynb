# %%
import numpy as np
import pandas as pd
import ssl
import copy
import matplotlib.pyplot as plt
import seaborn as sns #for data visualization
# %matplotlib inline
import re
import random
from pprint import pprint

from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 

from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import wordcloud  #for data visualization

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer

import scikitplot as skplt #for data visualization
import matplotlib.pyplot as plt

# %%
def clean_statement(statement):
    if type(statement)!= str:
        return statement
    statement = re.sub('$', ' ', statement)
    statement = re.sub('[^A-Za-z]+', ' ', statement)
    statement = re.sub('[,|.|?|\n]|\t', '', statement)
    statement = re.sub('n\'t', ' ', statement)
    statement = re.sub('submission|submissions|Submission|submission|th ', '', statement)
    statement = re.sub('one|two|given|need', '', statement)
    return statement

# %%
def process_problem_statement(q_statement):
    q_statement = clean_statement(q_statement)
    
    tokens = word_tokenize(q_statement)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in q_statement.lower().split() if i not in stoplist]
    
    ps = PorterStemmer()
    
    q_statement = ' '.join(word_list)
    
    return q_statement

# %%
def process_problem_solution(solution):
#     solution = clean_statement(solution)
    
    tokens = word_tokenize(solution)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in solution.lower().split() if i not in stoplist]
    
    solution = ' '.join(word_list)
    
    return solution

# %%
def process_tags(tag_col):
#     tags_present = list(re.split(',',tag_col))
    
    stoplist = set(stopwords.words('english'))
    word_list = [i for i in solution.lower().split() if i not in stoplist]
    
    tags_set = set(tags_present)
    tags_diff = tags_set.difference(set(all_tags_list))
    
    new_set = tags_set.difference(tags_diff)
    return list(new_set)

# %%
def get_all_distinct_tags(tags_col):
    print("get_all_distinct_tags")
    tags_list = []
    
    t_sets = set(tags_list)
    
    for row in tags_col:
        t_list = re.split(',',row)
        t_sets = t_sets.union(set(t_list))
    tags_list = list(t_sets)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in tags_list if i not in stoplist]
    
    return tags_list

# %%
def process_problem_Languages(lang_col):
    lang_col = clean_statement(lang_col)
    return lang_col

# %%
tags_list = ['dsu', 'trees', 'chinese remainder theorem', 'sortings', 'games', 'implementation', 'bitmasks',
              '*special', 'hashing', 'geometry', 'two pointers', 'combinatorics', 'flows', 'strings',
              'probabilities', 'data structures', 'ternary search', 'greedy', 'math', 'matrices',
              'divide and conquer', 'dfs and similar', 'constructive algorithms', 'brute force', 'dp',
              '2-sat', 'graph matchings', 'binary search', 'number theory', 'graphs', 'fft', 'shortest paths',
              'schedules', 'meet-in-the-middle', 'string suffix structures', 'expression parsing']

# %%
def validate_tags(tags):
    tags = eval(tags)
    i = 0
    while i<len(tags):
        if tags[i] not in tags_list:
            tags.remove(tags[i])
            continue
        i += 1
    return tags

# %%
def data_preprocessing():
    df = pd.read_csv("./codechef_questions.csv",encoding="ISO-8859-1")
    df = df.drop(['QCode','Title','link'],axis = 1)
    df["Languages"] = [process_problem_Languages(x) for x in df["Languages"]]
    
    for index, row in df.iterrows():
        tags = validate_tags(row['Tags'])
        if tags == []:
            df.drop(index, inplace=True)
        else:
            df.at[index, 'Tags'] = str(tags)
        
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    print(df["Tags"])

# %%
data_preprocessing()
# Out:
# 2                                    ['trees']
# 6                                       ['dp']
# 17                                      ['dp']
# 22                ['greedy', 'implementation']
# 24                                  ['greedy']
# 28                           ['combinatorics']
# 36                                      ['dp']
# 49                          ['implementation']
# 52                                  ['greedy']
# 53                                ['geometry']
# 54                                     ['fft']
# 66                                      ['dp']
# 67                                      ['dp']
# 71                                  ['greedy']
# 73                                    ['math']
# 86                                ['geometry']
# 87                                 ['strings']
# 90                     ['combinatorics', 'dp']
# 99                            ['dp', 'greedy']
# 103                                   ['math']
# 106                                     ['dp']
# 108                                  ['trees']
# 110                                     ['dp']
# 112                          ['combinatorics']
# 116                                ['strings']
# 118                                     ['dp']
# 120                               ['geometry']
# 140                         ['implementation']
# 141                          ['combinatorics']
# 145                                 ['greedy']
# 155                                ['hashing']
# 159                                 ['graphs']
# 162                                ['strings']
# 177                    ['combinatorics', 'dp']
# 178                         ['implementation']
# 182                               ['geometry']
# 183                                 ['greedy']
# 197                                 ['greedy']
# 203                                 ['greedy']
# 213                          ['combinatorics']
# 219                                     ['dp']
# 232                         ['implementation']
# 239                                     ['dp']
# 240                         ['implementation']
# 246                                   ['math']
# 248                                 ['greedy']
# 249                               ['geometry']
# 250                                ['strings']
# 251                               ['geometry']
# 254                                  ['trees']
# 256                                 ['graphs']
# 257                                 ['graphs']
# 259                                    ['fft']
# 260                                     ['dp']
# 265                    ['combinatorics', 'dp']
# 271                                     ['dp']
# 273                          ['combinatorics']
# 279                                 ['greedy']
# 290                                   ['math']
# 291                         ['implementation']
# 303                          ['combinatorics']
# 309                   ['dp', 'implementation']
# 310                                     ['dp']
# 321                                 ['greedy']
# 326                          ['dp', 'strings']
# 328                               ['geometry']
# 331             ['implementation', 'geometry']
# 332                                ['hashing']
# 348                                ['hashing']
# 351                                   ['math']
# 352                                     ['dp']
# 353                          ['combinatorics']
# 357                          ['combinatorics']
# 361                             ['math', 'dp']
# 364                          ['combinatorics']
# 369                          ['combinatorics']
# 373                          ['combinatorics']
# 383                                 ['greedy']
# 388                                     ['dp']
# 392                                 ['greedy']
# 398                                 ['graphs']
# 400                                  ['trees']
# 409                                  ['trees']
# 414                                ['strings']
# 415                                     ['dp']
# 417                               ['geometry']
# 418                                 ['greedy']
# 421                          ['combinatorics']
# 425                                     ['dp']
# 436                                     ['dp']
# 441                                 ['greedy']
# 442                                     ['dp']
# 445                                   ['math']
# 446                                 ['greedy']
# 453                         ['implementation']
# 454                                     ['dp']
# 456                                 ['greedy']
# 469                                    ['fft']
# 473                                     ['dp']
# 480                                     ['dp']
# 482                                 ['greedy']
# 492                        ['games', 'greedy']
# 493                          ['combinatorics']
# 496                         ['implementation']
# 502                                 ['greedy']
# 505                                 ['greedy']
# 508                                     ['dp']
# 509                                 ['greedy']
# 513                                 ['greedy']
# 524                                 ['greedy']
# 526                                ['hashing']
# 530                         ['implementation']
# 532                          ['combinatorics']
# 546                                ['strings']
# 554                                     ['dp']
# 556                                     ['dp']
# 559                                 ['greedy']
# 561                         ['implementation']
# 564                                ['hashing']
# 569                                    ['fft']
# 572                                     ['dp']
# 577                                 ['graphs']
# 590                                 ['greedy']
# 593                                 ['greedy']
# 602                                     ['dp']
# 604                                ['strings']
# 605                                 ['graphs']
# 609                          ['combinatorics']
# 612                           ['dp', 'greedy']
# 613                               ['matrices']
# 622                                ['strings']
# 623                               ['geometry']
# 626                                   ['math']
# 629                                 ['greedy']
# 637                                     ['dp']
# 649                                   ['math']
# 651             ['implementation', 'geometry']
# 652                   ['combinatorics', 'fft']
# 662                          ['dp', 'strings']
# 665                                    ['fft']
# 668                                     ['dp']
# 669                                     ['dp']
# 670                          ['combinatorics']
# 675                                     ['dp']
# 685                                     ['dp']
# 692                                     ['dp']
# 693                                  ['trees']
# 697                               ['geometry']
# 701                    ['combinatorics', 'dp']
# 703                                 ['greedy']
# 708                          ['combinatorics']
# 713                                     ['dp']
# 717                                 ['greedy']
# 720                                   ['math']
# 721                                    ['fft']
# 722                               ['matrices']
# 731                               ['geometry']
# 734                          ['combinatorics']
# 745                          ['combinatorics']
# 748                          ['combinatorics']
# 749                                 ['greedy']
# 756                          ['combinatorics']
# 757                               ['geometry']
# 763                     ['hashing', 'strings']
# 767                                   ['math']
# 773                    ['combinatorics', 'dp']
# 784                         ['implementation']
# 790                         ['implementation']
# 795                           ['dp', 'greedy']
# 796                                 ['greedy']
# 802                                   ['math']
# 809                                   ['math']
# 814                          ['combinatorics']
# 819                                     ['dp']
# 821                                     ['dp']
# 827                                 ['greedy']
# 831                                 ['greedy']
# 835                                     ['dp']
# 837                                   ['math']
# 840                   ['combinatorics', 'fft']
# 843                         ['implementation']
# 845                                     ['dp']
# 846                               ['geometry']
# 847                ['combinatorics', 'greedy']
# 856                                ['strings']
# 871                          ['combinatorics']
# 872                          ['combinatorics']
# 875                                 ['greedy']
# 878                        ['trees', 'graphs']
# 884                               ['geometry']
# 890                                  ['trees']
# 902                                     ['dp']
# 909                                 ['greedy']
# 911                               ['geometry']
# 933                                    ['fft']
# 939                                 ['graphs']
# 956                                 ['greedy']
# 960               ['greedy', 'implementation']
# 961                          ['combinatorics']
# 963                               ['geometry']
# 974                               ['geometry']
# 979                                     ['dp']
# 989                                     ['dp']
# 994                                     ['dp']
# 1003                              ['geometry']
# 1014              ['greedy', 'implementation']
# 1018                                ['greedy']
# 1036                               ['hashing']
# 1037                      ['math', 'geometry']
# 1048            ['implementation', 'geometry']
# 1058                               ['strings']
# 1062                                   ['fft']
# 1069                                    ['dp']
# 1070                                    ['dp']
# 1071                                    ['dp']
# 1077                                   ['fft']
# 1079                        ['implementation']
# 1088                              ['geometry']
# 1094             ['implementation', 'strings']
# 1100                                ['greedy']
# 1101                                    ['dp']
# 1102                                   ['fft']
# 1103                                    ['dp']
# 1105                                 ['trees']
# 1106                          ['dp', 'graphs']
# 1109                                 ['trees']
# 1110                          ['dp', 'greedy']
# 1121                                    ['dp']
# 1123                                ['greedy']
# 1124                              ['geometry']
# 1127                               ['hashing']
# 1128                                    ['dp']
# 1130                              ['geometry']
# 1138                                    ['dp']
# 1143                        ['implementation']
# 1144                               ['strings']
# 1145                                    ['dp']
# 1152                         ['combinatorics']
# 1154                                    ['dp']
# 1156                      ['greedy', 'graphs']
# 1158                               ['hashing']
# 1160                                    ['dp']
# 1162                                    ['dp']
# 1164                                    ['dp']
# 1165                                    ['dp']
# 1166                                ['greedy']
# 1168                                    ['dp']
# 1173                                ['greedy']
# 1174                           ['dp', 'trees']
# 1178                                ['greedy']
# 1181                                    ['dp']
# 1186                                ['greedy']
# 1189                         ['combinatorics']
# 1195                                ['greedy']
# 1198                                    ['dp']
# 1202                                  ['math']
# 1216                                    ['dp']
# 1220                         ['combinatorics']
# 1222                                    ['dp']
# 1223                                    ['dp']
# 1228             ['implementation', 'strings']
# 1229                                ['greedy']
# 1235                         ['combinatorics']
# 1239                                    ['dp']
# 1249                                ['greedy']
# 1253                                ['greedy']
# 1258                                ['graphs']
# 1261                                    ['dp']
# 1263                   ['combinatorics', 'dp']
# 1265                                    ['dp']
# 1268                         ['combinatorics']
# 1273                                    ['dp']
# 1275                        ['implementation']
# 1277                                ['greedy']
# 1278                                ['greedy']
# 1281                              ['geometry']
# 1282                           ['dp', 'trees']
# 1284                   ['combinatorics', 'dp']
# 1288                                    ['dp']
# 1292                  ['dp', 'implementation']
# 1294                         ['combinatorics']
# 1298                                    ['dp']
# 1299                                ['greedy']
# 1301                                    ['dp']
# 1306                                    ['dp']
# 1309                                ['greedy']
# 1321                      ['math', 'geometry']
# 1323                                ['greedy']
# 1326                         ['dp', 'strings']
# 1327                                ['greedy']
# 1332                                    ['dp']
# 1335                              ['geometry']
# 1338                              ['geometry']
# 1345                                ['greedy']
# 1348                                    ['dp']
# 1350                                ['greedy']
# 1356                                ['greedy']
# 1361                                    ['dp']
# 1365                                    ['dp']
# 1368                         ['combinatorics']
# 1381                               ['hashing']
# 1386                         ['combinatorics']
# 1401                                    ['dp']
# 1402                              ['geometry']
# 1404                                ['greedy']
# 1412            ['implementation', 'geometry']
# 1419                                ['greedy']
# 1421                                    ['dp']
# 1436    ['combinatorics', 'math', 'fft', 'dp']
# 1437                               ['hashing']
# 1441                                   ['dsu']
# 1451                         ['combinatorics']
# 1459                                    ['dp']
# 1466                                    ['dp']
# Name: Tags, dtype: object
